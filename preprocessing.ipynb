# %%
import pandas as pd

df = pd.read_csv('data\SensorHistory - motion-84b09769-1086-425f-be57-6258c205e074.csv')

#Dropping not important columns
columnsToDrop = ['GatewayID', 'Sensor Name', 'SensorID', 'Battery', 'DataMessageGUID', 'Voltage', 'Signal Strength', 'Raw Data', 'Sensor State']
#df.drop(columnsToDrop , axis=1, inplace=True)


df
# Out:
#                           DataMessageGUID  SensorID Sensor Name  \
# 0    9327cc5b-568e-4bcd-a89b-da8292eabdda    898918    Motion 1
# 1    d70435a1-6983-4b00-b0e8-149701792967    898918    Motion 1
# 2    9e9ea0ed-5bb7-4537-8a3a-ffc161f23aec    898918    Motion 1
# 3    69eca81e-b0ee-498f-94a9-64ea6e38068c    898918    Motion 1
# 4    a8bfffe7-365b-47e2-b743-263c32cb8bb3    898918    Motion 1
# ..                                    ...       ...         ...
# 701  5a91be76-de2f-4934-8095-5172fe61be30    898918    Motion 1
# 702  bee6fe84-e9b0-4f2b-b1b2-929468ba4a2a    898918    Motion 1
# 703  0c586f5f-a4d0-4f22-a198-999d66e40383    898918    Motion 1
# 704  6a79affc-ddee-431b-a5aa-7512bd3f99f2    898918    Motion 1
# 705  82a7e260-7655-4666-9eee-94b266aa6b11    898918    Motion 1
#
#                     Date  Value  Formatted Value  Battery  Raw Data  \
# 0     11/19/2022 8:09 AM      1  Motion Detected      100      True
# ...
